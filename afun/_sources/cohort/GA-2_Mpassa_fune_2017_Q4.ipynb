# %%
# Notebook parameters. Values here are for development only and
# will be overridden when running via snakemake and papermill.

config_file = "../../../config/agam.yaml"
cohort_id = "ML-2_Kati_colu_2014_Q3"
# cohort_id = "BF-09_Houet_colu_2012_Q3"
# cohort_id = "CD-NU_Gbadolite_gamb_2015_Q3"
# cohort_id = 'CI-LG_Agneby-Tiassa_colu_2012'

# %%
# Parameters
cohort_id = "GA-2_Mpassa_fune_2017_Q4"
config_file = "/home/runner/work/selection-atlas/selection-atlas/config/afun.yaml"

# %%
from bokeh.io import output_notebook
from IPython.display import Markdown
import numpy as np
import pandas as pd
import bokeh.layouts as bklay
import bokeh.plotting as bkplt
import bokeh.models as bkmod
from selection_atlas.setup import AtlasSetup
from selection_atlas.page_utils import AtlasPageUtils

# Initialise the atlas setup.
setup = AtlasSetup(config_file)
page_utils = AtlasPageUtils(setup=setup)

# N.B., do not add the "remove-output" tag to this cell!!! If you do,
# the bokeh javascript libraries will not get loaded in the generated
# HTML page. The call to output_notebook() injects javascript in the
# cell output which triggers the bokeh javascript libraries to be loaded
# in the page.
output_notebook(hide_banner=True)

# %%
# Load cohorts to find sample query to select samples for this cohort.
cohort = page_utils.gdf_cohorts.set_index("cohort_id").loc[cohort_id]
cohort
# Out:
# cohort_size                                                          26
# country                                                           Gabon
# admin1_iso                                                         GA-2
# admin1_name                                                 Haut-Ogooué
# admin2_name                                                      Mpassa
# taxon                                                          funestus
# year                                                               2017
# quarter                                                               4
# cohort_label                      Gabon / Mpassa / funestus / 2017 / Q4
# sample_query          cohort_admin2_quarter == 'GA-2_Mpassa_fune_201...
# h12_window_size                                                  7000.0
# g123_window_size                                                   2000
# country_alpha2                                                       GA
# country_alpha3                                                      GAB
# shapeName                                                        Mpassa
# shapeISO
# shapeID                                         22940354B20451079543442
# shapeGroup                                                          GAB
# shapeType                                                          ADM2
# representative_lon                                            13.597626
# representative_lat                                            -1.735709
# geometry              POLYGON ((13.274244612299071 -1.12922340823365...
# Name: GA-2_Mpassa_fune_2017_Q4, dtype: object

# %% [markdown]
# # Gabon / Mpassa / funestus / 2017 / Q4

# %%
# Load sample metadata for this cohort.
cohort_query = cohort["sample_query"]
df_samples = setup.malariagen_api.sample_metadata(
    sample_sets=setup.sample_sets, sample_query=cohort_query
)
df_samples
# Out:
#    sample_id    partner_sample_id  contributor country location  year  month  \
# 0   VBS17729  1230_GAB_D0260A_A01  Diego Ayala   Gabon  Benguia  2017     10
# 1   VBS17730  1230_GAB_D0260A_B01  Diego Ayala   Gabon  Benguia  2017     10
# 2   VBS17731  1230_GAB_D0260A_C01  Diego Ayala   Gabon  Benguia  2017     10
# 3   VBS17732  1230_GAB_D0260A_D01  Diego Ayala   Gabon  Benguia  2017     10
# 4   VBS17733  1230_GAB_D0260A_E01  Diego Ayala   Gabon  Benguia  2017     10
# 5   VBS17734  1230_GAB_D0260A_F01  Diego Ayala   Gabon  Benguia  2017     10
# 6   VBS17735  1230_GAB_D0260A_G01  Diego Ayala   Gabon  Benguia  2017     10
# 7   VBS17736  1230_GAB_D0260A_H01  Diego Ayala   Gabon  Benguia  2017     10
# 8   VBS17737  1230_GAB_D0260A_A02  Diego Ayala   Gabon  Benguia  2017     10
# 9   VBS17738  1230_GAB_D0260A_B02  Diego Ayala   Gabon  Benguia  2017     10
# 10  VBS17739  1230_GAB_D0260A_C02  Diego Ayala   Gabon  Benguia  2017     10
# 11  VBS17740  1230_GAB_D0260A_D02  Diego Ayala   Gabon  Benguia  2017     10
# 12  VBS17741  1230_GAB_D0260A_E02  Diego Ayala   Gabon  Benguia  2017     10
# 13  VBS17742  1230_GAB_D0260A_F02  Diego Ayala   Gabon  Benguia  2017     10
# 14  VBS17743  1230_GAB_D0260A_G02  Diego Ayala   Gabon  Benguia  2017     10
# 15  VBS17744  1230_GAB_D0260A_H02  Diego Ayala   Gabon  Benguia  2017     10
# 16  VBS17745  1230_GAB_D0260A_A03  Diego Ayala   Gabon  Benguia  2017     10
# 17  VBS17746  1230_GAB_D0260A_B03  Diego Ayala   Gabon  Benguia  2017     10
# 18  VBS17747  1230_GAB_D0260A_C03  Diego Ayala   Gabon  Benguia  2017     10
# 19  VBS17748  1230_GAB_D0260A_D03  Diego Ayala   Gabon  Benguia  2017     10
# 20  VBS17749  1230_GAB_D0260A_E03  Diego Ayala   Gabon  Benguia  2017     10
# 21  VBS17750  1230_GAB_D0260A_F03  Diego Ayala   Gabon  Benguia  2017     10
# 22  VBS17751  1230_GAB_D0260A_G03  Diego Ayala   Gabon  Benguia  2017     10
# 23  VBS17752  1230_GAB_D0260A_H03  Diego Ayala   Gabon  Benguia  2017     10
# 24  VBS17753  1230_GAB_D0260A_A04  Diego Ayala   Gabon  Benguia  2017     10
# 25  VBS17754  1230_GAB_D0260A_B04  Diego Ayala   Gabon  Benguia  2017     10
#
#     latitude  longitude sex_call  ...  admin1_name admin1_iso  admin2_name  \
# 0     -1.633     13.492        F  ...  Haut-Ogooué       GA-2       Mpassa
# 1     -1.633     13.492        F  ...  Haut-Ogooué       GA-2       Mpassa
# 2     -1.633     13.492        F  ...  Haut-Ogooué       GA-2       Mpassa
# 3     -1.633     13.492        F  ...  Haut-Ogooué       GA-2       Mpassa
# 4     -1.633     13.492        F  ...  Haut-Ogooué       GA-2       Mpassa
# 5     -1.633     13.492        F  ...  Haut-Ogooué       GA-2       Mpassa
# 6     -1.633     13.492        F  ...  Haut-Ogooué       GA-2       Mpassa
# 7     -1.633     13.492        F  ...  Haut-Ogooué       GA-2       Mpassa
# 8     -1.633     13.492        F  ...  Haut-Ogooué       GA-2       Mpassa
# 9     -1.633     13.492        F  ...  Haut-Ogooué       GA-2       Mpassa
# 10    -1.633     13.492        F  ...  Haut-Ogooué       GA-2       Mpassa
# 11    -1.633     13.492        F  ...  Haut-Ogooué       GA-2       Mpassa
# 12    -1.633     13.492        F  ...  Haut-Ogooué       GA-2       Mpassa
# 20  GA-2_Mpassa_fune_2017  GA-2_Mpassa_fune_2017_10  GA-2_Mpassa_fune_2017_Q4
# 21  GA-2_Mpassa_fune_2017  GA-2_Mpassa_fune_2017_10  GA-2_Mpassa_fune_2017_Q4
# 22  GA-2_Mpassa_fune_2017  GA-2_Mpassa_fune_2017_10  GA-2_Mpassa_fune_2017_Q4
# 23  GA-2_Mpassa_fune_2017  GA-2_Mpassa_fune_2017_10  GA-2_Mpassa_fune_2017_Q4
# 24  GA-2_Mpassa_fune_2017  GA-2_Mpassa_fune_2017_10  GA-2_Mpassa_fune_2017_Q4
# 25  GA-2_Mpassa_fune_2017  GA-2_Mpassa_fune_2017_10  GA-2_Mpassa_fune_2017_Q4
#
# [26 rows x 45 columns]

# %%
# Determine collection dates.
df_collection_dates = (
    df_samples.groupby(["year", "month"])
    .size()
    .reset_index()
    .rename(columns={0: "count"})
)
df_collection_dates
# Out:
#    year  month  count
# 0  2017     10     26

# %%
# Determine first and last collection months.

min_month = df_collection_dates["month"].min()
max_month = df_collection_dates["month"].max()

if min_month < 0:
    start_month = end_month = None
else:
    start_month = pd.to_datetime(min_month, format="%m").month_name()
    end_month = pd.to_datetime(max_month, format="%m").month_name()

start_month, end_month
# Out:
# ('October', 'October')

# %%
# Determine unique collection locations.
df_locations = df_samples[["location", "longitude", "latitude"]].drop_duplicates()
df_locations
# Out:
#   location  longitude  latitude
# 0  Benguia     13.492    -1.633

# %% [markdown]
# This cohort comprises 26 samples from the
# *funestus* taxon, collected from 1 locations within the administrative
# division of Mpassa, Haut-Ogooué, Gabon. Collections were made in October 2017.

# %% [markdown]
# ## Selection scans

# %%
# load signals to overlay on H12 plots.

dfs = []
for contig in setup.contigs:
    df = page_utils.load_cohort_signals(contig=contig, cohort_id=cohort_id)
    dfs.append(df)

df_signals = pd.concat(dfs)

# Add extra columns to help with overlaying signals on plots.
df_signals["bottom"] = 0
df_signals["top"] = 1

df_signals
# Out:
# Empty DataFrame
# Columns: [bottom, top]
# Index: []

# %%
# load window sizes
calibration_params = page_utils.load_gwss_calibration(cohort_id)
h12_window_size = calibration_params["h12_window_size"]
g123_window_size = calibration_params["g123_window_size"]
phasing_analysis = setup.taxon_phasing_analysis[cohort.taxon]
site_mask = setup.taxon_site_mask[cohort.taxon]


def plot_gwss(
    contig,
    df_signals,
    sizing_mode="stretch_width",
    show=False,
    width=800,
    track_height=150,
    genes_height=90,
    marker_size=2,
):
    # h12_palette = list(bkpal.BuPu4[0:1])
    h12_palette = ["black"]

    fig1 = setup.malariagen_api.plot_h12_gwss_track(
        contig=contig,
        window_size=h12_window_size,
        analysis=phasing_analysis,
        sample_sets=setup.sample_sets,
        sample_query=cohort_query,
        min_cohort_size=setup.min_cohort_size,
        max_cohort_size=setup.max_cohort_size,
        sizing_mode=sizing_mode,
        show=show,
        width=width,
        height=track_height,
        contig_colors=h12_palette,
    )
    fig1.xaxis.visible = False
    # Hack style for consistency with G123.
    for renderer in fig1.renderers:
        glyph = renderer.glyph
        glyph.line_color = "black"
        glyph.fill_color = None
        glyph.line_width = 1
        glyph.size = marker_size

    if not df_signals.empty:
        df = df_signals.query("contig == @contig")
        center_xs = [np.array([row.pcenter, row.pcenter]) for idx, row in df.iterrows()]
        center_ys = [np.array([0, 1]) for idx, row in df.iterrows()]
        source = bkmod.ColumnDataSource(
            data={
                "cohort": df.cohort_id,
                "contig": df.contig,
                "score": df.delta_i.astype(int),
                "peak_start": df.span2_pstart,
                "peak_stop": df.span2_pstop,
                "focus_start": df.focus_pstart,
                "focus_stop": df.focus_pstop,
                "center_xs": center_xs,
                "center_ys": center_ys,
                "bottom": df.bottom,
                "top": df.top,
            }
        )
        quad = fig1.quad(
            bottom="bottom",
            top="top",
            left="peak_start",
            right="peak_stop",
            source=source,
            color=page_utils.signal_span_color,
            alpha=page_utils.signal_span_alpha,
            line_width=1,
            level="underlay",
        )
        fig1.quad(
            bottom="bottom",
            top="top",
            left="focus_start",
            right="focus_stop",
            source=source,
            color=page_utils.signal_focus_color,
            alpha=page_utils.signal_focus_alpha,
            level="underlay",
        )
        glyph = bkmod.MultiLine(
            xs="center_xs",
            ys="center_ys",
            line_color=page_utils.signal_center_color,
            line_width=2,
            line_alpha=page_utils.signal_center_alpha,
        )
        fig1.add_glyph(source, glyph)

        hover = bkmod.HoverTool(
            tooltips=[
                ("Cohort", "@cohort"),
                ("Score", "@score"),
                ("Focus", "@focus_start{,} - @focus_stop{,}"),
            ],
            renderers=[quad],
        )

        fig1.add_tools(hover)

    fig2 = setup.malariagen_api.plot_g123_gwss_track(
        contig=contig,
        window_size=g123_window_size,
        sites=phasing_analysis,
        site_mask=phasing_analysis,
        sample_sets=setup.sample_sets,
        sample_query=cohort_query,
        min_cohort_size=setup.min_cohort_size,
        max_cohort_size=setup.max_cohort_size,
        sizing_mode=sizing_mode,
        width=width,
        height=track_height,
        show=show,
        title="",
        x_range=fig1.x_range,
    )
    fig2.xaxis.visible = False
    # Hack style for consistency with H12.
    for renderer in fig2.renderers:
        glyph = renderer.glyph
        glyph.line_color = "black"
        glyph.fill_color = None
        glyph.line_width = 1
        glyph.size = marker_size

    fig3 = setup.malariagen_api.plot_ihs_gwss_track(
        contig=contig,
        window_size=setup.ihs_window_size,
        analysis=phasing_analysis,
        sample_sets=setup.sample_sets,
        sample_query=cohort_query,
        min_cohort_size=setup.min_cohort_size,
        max_cohort_size=setup.max_cohort_size,
        sizing_mode=sizing_mode,
        width=width,
        height=track_height,
        show=show,
        title="",
        x_range=fig1.x_range,
    )
    fig3.xaxis.visible = False
    # Hack style for consistency with H12.
    for renderer in fig3.renderers:
        glyph = renderer.glyph
        # glyph.fill_color = None
        glyph.line_width = 1
        glyph.size = marker_size

    fig4 = setup.malariagen_api.plot_genes(
        region=contig,
        show=show,
        sizing_mode=sizing_mode,
        width=width,
        height=genes_height,
        x_range=fig1.x_range,
    )

    fig = bklay.gridplot(
        [fig1, fig2, fig3, fig4],
        ncols=1,
        toolbar_location="above",
        merge_tools=True,
        sizing_mode=sizing_mode,
    )
    return fig

# %%
for contig in setup.contigs:
    display(Markdown(f"### Chromosome {contig}"))

    fig = plot_gwss(
        contig=contig,
        df_signals=df_signals,
    )
    bkplt.show(fig)
# Out:
# ### Chromosome 2RL
#   <div id="c98c1aa7-e85a-40f0-bab6-82f0371ddb91" data-root-id="p1199" style="display: contents;"></div>
# ### Chromosome 3RL
#   <div id="d7445d89-f3e6-4520-9624-8f3d53ce218d" data-root-id="p1414" style="display: contents;"></div>
# ### Chromosome X
#   <div id="cde29afb-2edd-481a-b022-986ff0cc35c4" data-root-id="p1629" style="display: contents;"></div>

# %% [markdown]
# ## Sampling information

# %%
page_utils.plot_locations_map(cohort=cohort, df_samples=df_samples)
# Out:
# Map(center=[np.float64(-1.633), np.float64(13.492)], controls=(ZoomControl(options=['position', 'zoom_in_text'…

# %%
if min_month >= 0:
    # For this cohort we have month data, so show a breakdown of sample
    # numbers by location and month.

    # Construct a pivot table counting samples.
    df_loc_dt = df_samples.pivot_table(
        index=["location", "longitude", "latitude"],
        columns="month",
        values="sample_id",
        aggfunc="count",
        fill_value=0,
    )

    # Tidy up the columns using a multi index.
    df_loc_dt.reset_index(inplace=True)
    cols = pd.MultiIndex.from_tuples(
        [("Location", "Name"), ("Location", "Longitude"), ("Location", "Latitude")]
        + [
            ("Date", pd.to_datetime(x, format="%m").month_name())
            for x in df_loc_dt.columns[3:]
        ],
    )
    df_loc_dt.columns = cols

else:
    # For this cohort we do not have month data, so show a breakdown of sample
    # numbers by location only.

    # Construct a pivot table counting samples.
    df_loc_dt = df_samples.groupby(["location", "longitude", "latitude"]).agg(
        {"sample_id": "count"}
    )

    # Tidy up the columns using a multi index.
    df_loc_dt.reset_index(inplace=True)
    cols = pd.MultiIndex.from_tuples(
        [
            ("Location", "Name"),
            ("Location", "Longitude"),
            ("Location", "Latitude"),
            ("Date", cohort.year),
        ]
    )
    df_loc_dt.columns = cols

# Style the table.
df_loc_dt_styled = (
    df_loc_dt.style.format(precision=3)
    .set_caption("Table 1. Number of samples by location and month.")
    .hide(axis="index")
)
df_loc_dt_styled
# Out:
# <style type="text/css">
# </style>
# <table id="T_6fc5a">
#   <caption>Table 1. Number of samples by location and month.</caption>
#   <thead>
#     <tr>
#       <th id="T_6fc5a_level0_col0" class="col_heading level0 col0" colspan="3">Location</th>
#       <th id="T_6fc5a_level0_col3" class="col_heading level0 col3" >Date</th>
#     </tr>
#     <tr>
#       <th id="T_6fc5a_level1_col0" class="col_heading level1 col0" >Name</th>
#       <th id="T_6fc5a_level1_col1" class="col_heading level1 col1" >Longitude</th>
#       <th id="T_6fc5a_level1_col2" class="col_heading level1 col2" >Latitude</th>
#       <th id="T_6fc5a_level1_col3" class="col_heading level1 col3" >October</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6fc5a_row0_col0" class="data row0 col0" >Benguia</td>
#       <td id="T_6fc5a_row0_col1" class="data row0 col1" >13.492</td>
#       <td id="T_6fc5a_row0_col2" class="data row0 col2" >-1.633</td>
#       <td id="T_6fc5a_row0_col3" class="data row0 col3" >26</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Diagnostics
#
# ### H12 window size calibration

# %% [markdown]
# Selected window size: **7,000**

# %%
fig = setup.malariagen_api.plot_h12_calibration(
    contig=setup.h12_calibration_contig,
    analysis=phasing_analysis,
    sample_sets=setup.sample_sets,
    sample_query=cohort_query,
    min_cohort_size=setup.min_cohort_size,
    max_cohort_size=setup.max_cohort_size,
    window_sizes=setup.h12_calibration_window_sizes,
    show=False,
)
fig.y_range = bkmod.Range1d(0, 1)
bkplt.show(fig);
# Out:
#   <div id="e19f4540-775e-4ad6-a6b7-27cfb2e55d79" data-root-id="p1647" style="display: contents;"></div>

# %% [markdown]
# ### G123 window size calibration

# %% [markdown]
# Selected window size: **2,000**

# %%
fig = setup.malariagen_api.plot_g123_calibration(
    contig=setup.g123_calibration_contig,
    sites=phasing_analysis,
    site_mask=site_mask,
    sample_sets=setup.sample_sets,
    sample_query=cohort_query,
    min_cohort_size=setup.min_cohort_size,
    max_cohort_size=setup.max_cohort_size,
    window_sizes=setup.g123_calibration_window_sizes,
    show=False,
)
fig.y_range = bkmod.Range1d(0, 1)
bkplt.show(fig);
# Out:
#   <div id="fd581755-874a-40da-bb66-2e8712309b47" data-root-id="p1725" style="display: contents;"></div>

# %% [markdown]
# ## Data sources

# %%
page_utils.style_data_sources(
    df_samples=df_samples,
    caption="Table 2. Sample sets contributing data for this cohort.",
)
# Out:
# <style type="text/css">
# #T_1837b th {
#   text-align: left;
# }
# #T_1837b td {
#   text-align: left;
#   font-weight: normal;
# }
# </style>
# <table id="T_1837b">
#   <caption>Table 2. Sample sets contributing data for this cohort.</caption>
#   <thead>
#     <tr>
#       <th id="T_1837b_level0_col0" class="col_heading level0 col0" >Sample Set</th>
#       <th id="T_1837b_level0_col1" class="col_heading level0 col1" >Study</th>
#       <th id="T_1837b_level0_col2" class="col_heading level0 col2" >Contributor</th>
#       <th id="T_1837b_level0_col3" class="col_heading level0 col3" >Data Release</th>
#       <th id="T_1837b_level0_col4" class="col_heading level0 col4" >Citation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1837b_row0_col0" class="data row0 col0" >1230-VO-GA-CF-AYALA-VMF00045</td>
#       <td id="T_1837b_row0_col1" class="data row0 col1" ><a href="https://www.malariagen.net/partner_study/1230-VO-MULTI-AYALA" target="_blank">1230-VO-MULTI-AYALA</a></td>
#       <td id="T_1837b_row0_col2" class="data row0 col2" >Diego Ayala</td>
#       <td id="T_1837b_row0_col3" class="data row0 col3" ><a href="https://malariagen.github.io/vector-data/af1/af1.0.html" target="_blank">Af1.0</a></td>
#       <td id="T_1837b_row0_col4" class="data row0 col4" ><a href='https://pmc.ncbi.nlm.nih.gov/articles/PMC11702533/' target='_blank'>Boddé, Nwezeobi et al. 2024</a></td>
#     </tr>
#   </tbody>
# </table>
