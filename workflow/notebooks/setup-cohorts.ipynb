# %%
import yaml
import pandas as pd
import malariagen_data
from pyprojroot import here

# %%
with open(here() / "workflow" / "params.yaml") as params_file:
    params = yaml.safe_load(params_file)
params
# Out:
# {'min_cohort_size': 20, 'releases': {'ag': ['3.0']}}

# %%
ag3 = malariagen_data.Ag3(
    # TODO in production build, remove use of simplecache if running inside google cloud
    url="simplecache::gs://vo_agam_release",
    simplecache=dict(cache_storage=(here() / "gcs_cache").as_posix()),
    results_cache=(here() / "malariagen_data_cache").as_posix(),
)
ag3
# Out:
# <MalariaGEN Ag3 API client>
# Storage URL             : simplecache::gs://vo_agam_release
# Data releases available : 3.0
# Results cache           : /home/aliman/github/anopheles-genomics-surveillance/selection-atlas/malariagen_data_cache
# Cohorts analysis        : 20220608
# Species analysis        : aim_20220528
# Site filters analysis   : dt_20200416
# Software version        : malariagen_data 7.3.0
# Client location         : England, GB
# ---
# Please note that data are subject to terms of use,
# for more information see https://www.malariagen.net/data
# or contact data@malariagen.net. For API documentation see
# https://malariagen.github.io/vector-data/ag3/api.html

# %%
df_samples = ag3.sample_metadata(sample_sets=params["releases"]["ag"])
df_samples
# Out:
# Load sample metadata:   0%|          | 0/28 [00:00<?, ?it/s]
#      sample_id partner_sample_id      contributor    country location  year  \
# 0     AR0047-C            LUA047       Joao Pinto     Angola   Luanda  2009
# 1     AR0049-C            LUA049       Joao Pinto     Angola   Luanda  2009
# 2     AR0051-C            LUA051       Joao Pinto     Angola   Luanda  2009
# 3     AR0061-C            LUA061       Joao Pinto     Angola   Luanda  2009
# 4     AR0078-C            LUA078       Joao Pinto     Angola   Luanda  2009
# ...        ...               ...              ...        ...      ...   ...
# 3076  AD0494-C         80-2-o-16  Martin Donnelly  Lab Cross     LSTM    -1
# 3077  AD0495-C         80-2-o-17  Martin Donnelly  Lab Cross     LSTM    -1
# 3078  AD0496-C         80-2-o-18  Martin Donnelly  Lab Cross     LSTM    -1
# 3079  AD0497-C         80-2-o-19  Martin Donnelly  Lab Cross     LSTM    -1
# 3080  AD0498-C         80-2-o-20  Martin Donnelly  Lab Cross     LSTM    -1
#
#       month  latitude  longitude sex_call  ...                    aim_species  \
# 0         4    -8.884     13.302        F  ...                       coluzzii
# 1         4    -8.884     13.302        F  ...                       coluzzii
# 2         4    -8.884     13.302        F  ...                       coluzzii
# 3         4    -8.884     13.302        F  ...                       coluzzii
# 4         4    -8.884     13.302        F  ...                       coluzzii
# ...     ...       ...        ...      ...  ...                            ...
# 3076     -1    53.409     -2.969        F  ...  intermediate_gambiae_coluzzii
# 3077     -1    53.409     -2.969        M  ...  intermediate_gambiae_coluzzii
# 3078     -1    53.409     -2.969        M  ...  intermediate_gambiae_coluzzii
# 3079     -1    53.409     -2.969        F  ...  intermediate_gambiae_coluzzii
# 3080     -1    53.409     -2.969        M  ...  intermediate_gambiae_coluzzii
#
#      country_iso  admin1_name  admin1_iso  admin2_name  \
# 0            AGO       Luanda      AO-LUA       Luanda
# 1            AGO       Luanda      AO-LUA       Luanda
# 2            AGO       Luanda      AO-LUA       Luanda
# 3            AGO       Luanda      AO-LUA       Luanda
# 4            AGO       Luanda      AO-LUA       Luanda
# ...          ...          ...         ...          ...
# 3076         NaN          NaN         NaN          NaN
# 3077         NaN          NaN         NaN          NaN
# 3078         NaN          NaN         NaN          NaN
# 3079         NaN          NaN         NaN          NaN
# 3080         NaN          NaN         NaN          NaN
#
#                               taxon cohort_admin1_year  cohort_admin1_month  \
# 0                          coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 1                          coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 2                          coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 3                          coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 4                          coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04
# ...                             ...                ...                  ...
# 3076  intermediate_gambiae_coluzzii                NaN                  NaN
# 3077  intermediate_gambiae_coluzzii                NaN                  NaN
# 3078  intermediate_gambiae_coluzzii                NaN                  NaN
# 3079  intermediate_gambiae_coluzzii                NaN                  NaN
# 3080  intermediate_gambiae_coluzzii                NaN                  NaN
#
#            cohort_admin2_year         cohort_admin2_month
# 0     AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
# 1     AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
# 2     AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
# 3     AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
# 4     AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
# ...                       ...                         ...
# 3076                      NaN                         NaN
# 3077                      NaN                         NaN
# 3078                      NaN                         NaN
# 3079                      NaN                         NaN
# 3080                      NaN                         NaN
#
# [3081 rows x 27 columns]

# %%
# TODO change this to quarter when available
cohorts_col = "cohort_admin2_year"

# %%
df_cohorts_selected = (
    df_samples
        .groupby(cohorts_col).agg({
        'sample_id': 'count',
        'country': 'first',
        'admin1_iso': 'first',
        'admin1_name': 'first',
        'admin2_name': 'first',
        'taxon': 'first',
        'year': 'first',
    })
    .reset_index()
    .rename(columns={
        'sample_id': 'cohort_size',
        cohorts_col: 'cohort_id',
    })
    .query(f'cohort_size >= {params["min_cohort_size"]}')
)
df_cohorts_selected['cohort_label'] = df_cohorts_selected.apply(
    lambda row: f"{row.country} / {row.admin2_name} / {row.taxon} / {row.year}",
    axis="columns",
)
df_cohorts_selected['sample_query'] = df_cohorts_selected.apply(
    lambda row: f"{cohorts_col} == '{row.cohort_id}'",
    axis="columns",
)
df_cohorts_selected
# Out:
#                                      cohort_id  cohort_size  \
# 0                      AO-LUA_Luanda_colu_2009           81
# 3                        BF-09_Houet_colu_2012           82
# 4                        BF-09_Houet_colu_2014           53
# 5                        BF-09_Houet_gamb_2012           98
# 6                        BF-09_Houet_gamb_2014           46
# 7                    CD-NU_Gbadolite_gamb_2015           76
# 11                     CF-BGF_Bangui_gamb_1994           53
# 12               CI-LG_Agneby-Tiassa_colu_2012           80
# 26                  CM-ES_Haut-Nyong_gamb_2009          110
# 27               CM-ES_Lom-Et-Djérem_gamb_2009          193
# 43                     FR-YT_Mayotte_gamb_2011           23
# 44                   GA-1_Libreville_gamb_2000           69
# 47  GH-CP_Twifu-Heman-Lower-Denkyira_colu_2012           25
# 49                  GH-EP_New-Juaben_gamb_2012           23
# 50           GH-WP_Shama-Ahanta-East_colu_2012           24
# 55                 GM-M_Fulladu-West_gcx2_2012          160
# 56              GM-N_Central-Baddibu_gcx1_2011           68
# 61                  GN-F_Kissidougou_gamb_2012           60
# 63                      GN-N_Macenta_gamb_2012           63
# 65              GW-BM_Setor-De-Safim_gcx1_2010           33
# 66    GW-BS_Bissau-Autonomous-Sector_gcx1_2010           60
# 71                      KE-14_Kilifi_gcx3_2012           54
# 72                      ML-2_Kangaba_gamb_2004           23
# 74                         ML-2_Kati_colu_2014           27
# 76                         ML-2_Kati_gamb_2014           33
# 77                    ML-3_Yanfolila_colu_2012           28
# 78                    ML-3_Yanfolila_gamb_2012           65
# 84                     MW-S_Chikwawa_arab_2015           41
# 86                   MZ-I_Morrumbene_gamb_2004           71
# 87                      TZ-05_Muleba_arab_2015          137
# 88                      TZ-05_Muleba_gamb_2015           32
# 90                      TZ-13_Tarime_arab_2012           47
# 92                      TZ-25_Muheza_gamb_2013           32
# 94                       TZ-26_Moshi_arab_2012           40
# 95                       UG-E_Tororo_arab_2012           81
# 96                       UG-E_Tororo_gamb_2012          112
# 98                      UG-W_Kanungu_gamb_2012           95
#
#                              country admin1_iso      admin1_name  \
# 0                             Angola     AO-LUA           Luanda
# 3                       Burkina Faso      BF-09    Hauts-Bassins
# 4                       Burkina Faso      BF-09    Hauts-Bassins
# 5                       Burkina Faso      BF-09    Hauts-Bassins
# 6                       Burkina Faso      BF-09    Hauts-Bassins
# 7   Democratic Republic of the Congo      CD-NU      Nord-Ubangi
# 11          Central African Republic     CF-BGF           Bangui
# 12                     Cote d'Ivoire      CI-LG          Lagunes
# 26                          Cameroon      CM-ES             East
# 27                          Cameroon      CM-ES             East
# 43                           Mayotte      FR-YT          Mayotte
# 44                             Gabon       GA-1         Estuaire
# 47                             Ghana      GH-CP          Central
# 49                             Ghana      GH-EP          Eastern
# 50                             Ghana      GH-WP          Western
# 55                       Gambia, The       GM-M      Janjanbureh
# 56                       Gambia, The       GM-N          Kerewan
# 61                            Guinea       GN-F          Faranah
# 63                            Guinea       GN-N        Nzerekore
# 65                     Guinea-Bissau      GW-BM           Biombo
# 66                     Guinea-Bissau      GW-BS           Bissau
# 71                             Kenya      KE-14           Kilifi
# 72                              Mali       ML-2       Koulikouro
# 74                              Mali       ML-2       Koulikouro
# 76                              Mali       ML-2       Koulikouro
# 77                              Mali       ML-3          Sikasso
# 78                              Mali       ML-3          Sikasso
# 84                            Malawi       MW-S  Southern Region
# 86                        Mozambique       MZ-I        Inhambane
# 87                          Tanzania      TZ-05           Kagera
# 88                          Tanzania      TZ-05           Kagera
# 90                          Tanzania      TZ-13             Mara
# 92                          Tanzania      TZ-25            Tanga
# 94                          Tanzania      TZ-26          Manyara
# 95                            Uganda       UG-E   Eastern Region
# 96                            Uganda       UG-E   Eastern Region
# 98                            Uganda       UG-W   Western Region
#
#                    admin2_name       taxon  year  \
# 0                       Luanda    coluzzii  2009
# 3                        Houet    coluzzii  2012
# 4                        Houet    coluzzii  2014
# 5                        Houet     gambiae  2012
# 6                        Houet     gambiae  2014
# 7                    Gbadolite     gambiae  2015
# 11                      Bangui     gambiae  1994
# 12               Agneby-Tiassa    coluzzii  2012
# 26                  Haut-Nyong     gambiae  2009
# 27               Lom-Et-Djérem     gambiae  2009
# 43                     Mayotte     gambiae  2011
# 44                  Libreville     gambiae  2000
# 47  Twifu Heman/Lower Denkyira    coluzzii  2012
# 49                  New Juaben     gambiae  2012
# 50           Shama Ahanta East    coluzzii  2012
# 55                Fulladu West        gcx2  2012
# 56             Central Baddibu        gcx1  2011
# 61                 Kissidougou     gambiae  2012
# 63                     Macenta     gambiae  2012
# 65              Setor De Safim        gcx1  2010
# 66    Bissau Autonomous Sector        gcx1  2010
# 71                      Kilifi        gcx3  2012
# 72                     Kangaba     gambiae  2004
# 74                        Kati    coluzzii  2014
# 76                        Kati     gambiae  2014
# 77                   Yanfolila    coluzzii  2012
# 78                   Yanfolila     gambiae  2012
# 84                    Chikwawa  arabiensis  2015
# 86                  Morrumbene     gambiae  2004
# 87                      Muleba  arabiensis  2015
# 88                      Muleba     gambiae  2015
# 90                      Tarime  arabiensis  2012
# 92                      Muheza     gambiae  2013
# 94                       Moshi  arabiensis  2012
# 95                      Tororo  arabiensis  2012
# 96                      Tororo     gambiae  2012
# 98                     Kanungu     gambiae  2012
#
#                                          cohort_label  \
# 0                   Angola / Luanda / coluzzii / 2009
# 3              Burkina Faso / Houet / coluzzii / 2012
# 4              Burkina Faso / Houet / coluzzii / 2014
# 5               Burkina Faso / Houet / gambiae / 2012
# 6               Burkina Faso / Houet / gambiae / 2014
# 7   Democratic Republic of the Congo / Gbadolite /...
# 11  Central African Republic / Bangui / gambiae / ...
# 12    Cote d'Ivoire / Agneby-Tiassa / coluzzii / 2012
# 26             Cameroon / Haut-Nyong / gambiae / 2009
# 27          Cameroon / Lom-Et-Djérem / gambiae / 2009
# 43                 Mayotte / Mayotte / gambiae / 2011
# 44                Gabon / Libreville / gambiae / 2000
# 47  Ghana / Twifu Heman/Lower Denkyira / coluzzii ...
# 49                Ghana / New Juaben / gambiae / 2012
# 50        Ghana / Shama Ahanta East / coluzzii / 2012
# 55           Gambia, The / Fulladu West / gcx2 / 2012
# 56        Gambia, The / Central Baddibu / gcx1 / 2011
# 61              Guinea / Kissidougou / gambiae / 2012
# 63                  Guinea / Macenta / gambiae / 2012
# 65       Guinea-Bissau / Setor De Safim / gcx1 / 2010
# 66  Guinea-Bissau / Bissau Autonomous Sector / gcx...
# 71                       Kenya / Kilifi / gcx3 / 2012
# 72                    Mali / Kangaba / gambiae / 2004
# 74                      Mali / Kati / coluzzii / 2014
# 76                       Mali / Kati / gambiae / 2014
# 77                 Mali / Yanfolila / coluzzii / 2012
# 78                  Mali / Yanfolila / gambiae / 2012
# 84              Malawi / Chikwawa / arabiensis / 2015
# 86           Mozambique / Morrumbene / gambiae / 2004
# 87              Tanzania / Muleba / arabiensis / 2015
# 88                 Tanzania / Muleba / gambiae / 2015
# 90              Tanzania / Tarime / arabiensis / 2012
# 92                 Tanzania / Muheza / gambiae / 2013
# 94               Tanzania / Moshi / arabiensis / 2012
# 95                Uganda / Tororo / arabiensis / 2012
# 96                   Uganda / Tororo / gambiae / 2012
# 98                  Uganda / Kanungu / gambiae / 2012
#
#                                          sample_query
# 0     cohort_admin2_year == 'AO-LUA_Luanda_colu_2009'
# 3       cohort_admin2_year == 'BF-09_Houet_colu_2012'
# 4       cohort_admin2_year == 'BF-09_Houet_colu_2014'
# 5       cohort_admin2_year == 'BF-09_Houet_gamb_2012'
# 6       cohort_admin2_year == 'BF-09_Houet_gamb_2014'
# 7   cohort_admin2_year == 'CD-NU_Gbadolite_gamb_2015'
# 11    cohort_admin2_year == 'CF-BGF_Bangui_gamb_1994'
# 12  cohort_admin2_year == 'CI-LG_Agneby-Tiassa_col...
# 26  cohort_admin2_year == 'CM-ES_Haut-Nyong_gamb_2...
# 27  cohort_admin2_year == 'CM-ES_Lom-Et-Djérem_gam...
# 43    cohort_admin2_year == 'FR-YT_Mayotte_gamb_2011'
# 44  cohort_admin2_year == 'GA-1_Libreville_gamb_2000'
# 47  cohort_admin2_year == 'GH-CP_Twifu-Heman-Lower...
# 49  cohort_admin2_year == 'GH-EP_New-Juaben_gamb_2...
# 50  cohort_admin2_year == 'GH-WP_Shama-Ahanta-East...
# 55  cohort_admin2_year == 'GM-M_Fulladu-West_gcx2_...
# 56  cohort_admin2_year == 'GM-N_Central-Baddibu_gc...
# 61  cohort_admin2_year == 'GN-F_Kissidougou_gamb_2...
# 63     cohort_admin2_year == 'GN-N_Macenta_gamb_2012'
# 65  cohort_admin2_year == 'GW-BM_Setor-De-Safim_gc...
# 66  cohort_admin2_year == 'GW-BS_Bissau-Autonomous...
# 71     cohort_admin2_year == 'KE-14_Kilifi_gcx3_2012'
# 72     cohort_admin2_year == 'ML-2_Kangaba_gamb_2004'
# 74        cohort_admin2_year == 'ML-2_Kati_colu_2014'
# 76        cohort_admin2_year == 'ML-2_Kati_gamb_2014'
# 77   cohort_admin2_year == 'ML-3_Yanfolila_colu_2012'
# 78   cohort_admin2_year == 'ML-3_Yanfolila_gamb_2012'
# 84    cohort_admin2_year == 'MW-S_Chikwawa_arab_2015'
# 86  cohort_admin2_year == 'MZ-I_Morrumbene_gamb_2004'
# 87     cohort_admin2_year == 'TZ-05_Muleba_arab_2015'
# 88     cohort_admin2_year == 'TZ-05_Muleba_gamb_2015'
# 90     cohort_admin2_year == 'TZ-13_Tarime_arab_2012'
# 92     cohort_admin2_year == 'TZ-25_Muheza_gamb_2013'
# 94      cohort_admin2_year == 'TZ-26_Moshi_arab_2012'
# 95      cohort_admin2_year == 'UG-E_Tororo_arab_2012'
# 96      cohort_admin2_year == 'UG-E_Tororo_gamb_2012'
# 98     cohort_admin2_year == 'UG-W_Kanungu_gamb_2012'

# %%
df_cohorts_selected.to_csv("../cohorts.csv", index=False)
