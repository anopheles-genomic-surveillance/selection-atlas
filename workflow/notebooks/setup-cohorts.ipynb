# %%
import yaml
import pandas as pd
import malariagen_data
from pyprojroot import here

# %%
with open(here() / "workflow" / "params.yaml") as params_file:
    params = yaml.safe_load(params_file)
params
# Out:
# {'min_cohort_size': 20,
#  'max_cohort_size': 50,
#  'ag': {'sample_sets': ['3.0'],
#   'contigs': ['2R', '3R', 'X'],
#   'cohorts_analysis': '20230223',
#   'h12_calibration_contig': '3L'}}

# %%
ag3 = malariagen_data.Ag3(
    # TODO in production build, remove use of simplecache if running inside google cloud
    # url = "gs://vo_agam_release",
    url="simplecache::gs://vo_agam_release",
    # pin the version of the cohorts analysis for reproducibility
    cohorts_analysis=params["ag"]["cohorts_analysis"],
    # TODO remove simplecache config in production
    simplecache=dict(cache_storage=(here() / "gcs_cache").as_posix()),
    results_cache=(here() / "malariagen_data_cache").as_posix(),
)
ag3
# Out:
# <MalariaGEN Ag3 API client>
# Storage URL             : simplecache::gs://vo_agam_release
# Data releases available : 3.0
# Results cache           : /home/aliman/github/anopheles-genomics-surveillance/selection-atlas/malariagen_data_cache
# Cohorts analysis        : 20230223
# Species analysis        : aim_20220528
# Site filters analysis   : dt_20200416
# Software version        : malariagen_data 7.3.0
# Client location         : England, GB
# ---
# Please note that data are subject to terms of use,
# for more information see https://www.malariagen.net/data
# or contact data@malariagen.net. For API documentation see
# https://malariagen.github.io/vector-data/ag3/api.html

# %%
df_samples = ag3.sample_metadata(sample_sets=params["ag"]["sample_sets"])
# Out:
# Load sample metadata:   0%|          | 0/28 [00:00<?, ?it/s]

# %%
def month_to_quarter(row):
    return ((row.month - 1) // 3) + 1 if row.month > 0 else -1

# %%
# add a "quarter" column for convenience
df_samples["quarter"] = df_samples.apply(
    month_to_quarter,
    axis="columns"
)
df_samples
# Out:
#      sample_id partner_sample_id      contributor    country location  year  \
# 0     AR0047-C            LUA047       Joao Pinto     Angola   Luanda  2009
# 1     AR0049-C            LUA049       Joao Pinto     Angola   Luanda  2009
# 2     AR0051-C            LUA051       Joao Pinto     Angola   Luanda  2009
# 3     AR0061-C            LUA061       Joao Pinto     Angola   Luanda  2009
# 4     AR0078-C            LUA078       Joao Pinto     Angola   Luanda  2009
# ...        ...               ...              ...        ...      ...   ...
# 3076  AD0494-C         80-2-o-16  Martin Donnelly  Lab Cross     LSTM    -1
# 3077  AD0495-C         80-2-o-17  Martin Donnelly  Lab Cross     LSTM    -1
# 3078  AD0496-C         80-2-o-18  Martin Donnelly  Lab Cross     LSTM    -1
# 3079  AD0497-C         80-2-o-19  Martin Donnelly  Lab Cross     LSTM    -1
# 3080  AD0498-C         80-2-o-20  Martin Donnelly  Lab Cross     LSTM    -1
#
#       month  latitude  longitude sex_call  ... admin1_iso admin2_name  \
# 0         4    -8.884     13.302        F  ...     AO-LUA      Luanda
# 1         4    -8.884     13.302        F  ...     AO-LUA      Luanda
# 2         4    -8.884     13.302        F  ...     AO-LUA      Luanda
# 3         4    -8.884     13.302        F  ...     AO-LUA      Luanda
# 4         4    -8.884     13.302        F  ...     AO-LUA      Luanda
# ...     ...       ...        ...      ...  ...        ...         ...
# 3076     -1    53.409     -2.969        F  ...        NaN         NaN
# 3077     -1    53.409     -2.969        M  ...        NaN         NaN
# 3078     -1    53.409     -2.969        M  ...        NaN         NaN
# 3079     -1    53.409     -2.969        F  ...        NaN         NaN
# 3080     -1    53.409     -2.969        M  ...        NaN         NaN
#
#            taxon  cohort_admin1_year  cohort_admin1_month  \
# 0       coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 1       coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 2       coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 3       coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 4       coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04
# ...          ...                 ...                  ...
# 3076  unassigned                 NaN                  NaN
# 3077  unassigned                 NaN                  NaN
# 3078  unassigned                 NaN                  NaN
# 3079  unassigned                 NaN                  NaN
# 3080  unassigned                 NaN                  NaN
#
#      cohort_admin1_quarter       cohort_admin2_year  \
# 0      AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# 1      AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# 2      AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# 3      AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# 4      AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# ...                    ...                      ...
# 3076                   NaN                      NaN
# 3077                   NaN                      NaN
# 3078                   NaN                      NaN
# 3079                   NaN                      NaN
# 3080                   NaN                      NaN
#
#              cohort_admin2_month       cohort_admin2_quarter quarter
# 0     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2       2
# 1     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2       2
# 2     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2       2
# 3     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2       2
# 4     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2       2
# ...                          ...                         ...     ...
# 3076                         NaN                         NaN      -1
# 3077                         NaN                         NaN      -1
# 3078                         NaN                         NaN      -1
# 3079                         NaN                         NaN      -1
# 3080                         NaN                         NaN      -1
#
# [3081 rows x 30 columns]

# %%
# check the quarter logic
df_samples.groupby("quarter").agg({'month': lambda v: set(v)})
# Out:
#                 month
# quarter
# -1               {-1}
#  1          {1, 2, 3}
#  2          {4, 5, 6}
#  3          {8, 9, 7}
#  4       {10, 11, 12}

# %%
cohorts_col = "cohort_admin2_quarter"

# %%
def make_cohort_label(row):
    # N.B., not all cohorts have a quarter defined, because samples were not provided
    # with collection month in the metadata. In this case we expect to fall back to
    # year.
    if row.quarter > 0:
        return f"{row.country} / {row.admin2_name} / {row.taxon} / {row.year} / Q{row.quarter}"
    else:
        return f"{row.country} / {row.admin2_name} / {row.taxon} / {row.year}"

# %%
df_cohorts_selected = (
    df_samples
    # N.B., only include females, otherwise data on X chromosome will be wonky
    .query("sex_call == 'F'")
    .groupby(cohorts_col).agg({
        'sample_id': 'count',
        'country': 'first',
        'admin1_iso': 'first',
        'admin1_name': 'first',
        'admin2_name': 'first',
        'taxon': 'first',
        'year': 'first',
        'quarter': 'first',
    })
    .reset_index()
    .rename(columns={
        'sample_id': 'cohort_size',
        cohorts_col: 'cohort_id',
    })
    .query(f'cohort_size >= {params["min_cohort_size"]}')
)
df_cohorts_selected['cohort_label'] = df_cohorts_selected.apply(
    make_cohort_label,
    axis="columns",
)
df_cohorts_selected['sample_query'] = df_cohorts_selected.apply(
    # N.B., only include females, otherwise data on X chromosome will be wonky
    lambda row: f"{cohorts_col} == '{row.cohort_id}' and sex_call == 'F'",
    axis="columns",
)
df_cohorts_selected
# Out:
#                                          cohort_id  cohort_size  \
# 0                       AO-LUA_Luanda_colu_2009_Q2           77
# 4                         BF-09_Houet_colu_2012_Q3           78
# 5                         BF-09_Houet_colu_2014_Q3           32
# 6                         BF-09_Houet_gamb_2012_Q3           73
# 7                         BF-09_Houet_gamb_2014_Q3           41
# 8                     CD-NU_Gbadolite_gamb_2015_Q3           44
# 12                      CF-BGF_Bangui_gamb_1994_Q1           53
# 13                   CI-LG_Agneby-Tiassa_colu_2012           80
# 27                   CM-ES_Haut-Nyong_gamb_2009_Q3           95
# 28                CM-ES_Lom-Et-Djérem_gamb_2009_Q3          163
# 45                    GA-1_Libreville_gamb_2000_Q4           69
# 48   GH-CP_Twifu-Heman-Lower-Denkyira_colu_2012_Q3           25
# 50                   GH-EP_New-Juaben_gamb_2012_Q4           23
# 51            GH-WP_Shama-Ahanta-East_colu_2012_Q3           24
# 54                  GM-M_Fulladu-West_gcx2_2012_Q4          172
# 55               GM-N_Central-Baddibu_gcx1_2011_Q3           52
# 60                   GN-F_Kissidougou_gamb_2012_Q4           50
# 62                       GN-N_Macenta_gamb_2012_Q4           51
# 64                  GW-BM_Setor-De-Safim_gcx1_2010           33
# 65        GW-BS_Bissau-Autonomous-Sector_gcx1_2010           60
# 70                          KE-14_Kilifi_gcx3_2012           54
# 71                       ML-2_Kangaba_gamb_2004_Q3           23
# 73                          ML-2_Kati_colu_2014_Q3           27
# 75                          ML-2_Kati_gamb_2014_Q3           24
# 76                     ML-3_Yanfolila_colu_2012_Q4           23
# 77                     ML-3_Yanfolila_gamb_2012_Q4           53
# 83                      MW-S_Chikwawa_arab_2015_Q2           41
# 85                    MZ-I_Morrumbene_gamb_2004_Q1           49
# 86                    MZ-I_Morrumbene_gamb_2004_Q2           22
# 87                       TZ-05_Muleba_arab_2015_Q1           39
# 88                       TZ-05_Muleba_arab_2015_Q2           98
# 92                       TZ-13_Tarime_arab_2012_Q3           47
# 94                       TZ-25_Muheza_gamb_2013_Q1           32
# 96                        TZ-26_Moshi_arab_2012_Q3           39
# 97                        UG-E_Tororo_arab_2012_Q4           81
# 98                        UG-E_Tororo_gamb_2012_Q4          112
# 100                      UG-W_Kanungu_gamb_2012_Q4           95
#
#                               country admin1_iso      admin1_name  \
# 0                              Angola     AO-LUA           Luanda
# 4                        Burkina Faso      BF-09    Hauts-Bassins
# 5                        Burkina Faso      BF-09    Hauts-Bassins
# 6                        Burkina Faso      BF-09    Hauts-Bassins
# 7                        Burkina Faso      BF-09    Hauts-Bassins
# 8    Democratic Republic of the Congo      CD-NU      Nord-Ubangi
# 12           Central African Republic     CF-BGF           Bangui
# 13                      Cote d'Ivoire      CI-LG          Lagunes
# 27                           Cameroon      CM-ES             East
# 28                           Cameroon      CM-ES             East
# 45                              Gabon       GA-1         Estuaire
# 48                              Ghana      GH-CP          Central
# 50                              Ghana      GH-EP          Eastern
# 51                              Ghana      GH-WP          Western
# 54                        Gambia, The       GM-M      Janjanbureh
# 55                        Gambia, The       GM-N          Kerewan
# 60                             Guinea       GN-F          Faranah
# 62                             Guinea       GN-N        Nzerekore
# 64                      Guinea-Bissau      GW-BM           Biombo
# 65                      Guinea-Bissau      GW-BS           Bissau
# 70                              Kenya      KE-14           Kilifi
# 71                               Mali       ML-2       Koulikouro
# 73                               Mali       ML-2       Koulikouro
# 75                               Mali       ML-2       Koulikouro
# 76                               Mali       ML-3          Sikasso
# 77                               Mali       ML-3          Sikasso
# 83                             Malawi       MW-S  Southern Region
# 85                         Mozambique       MZ-I        Inhambane
# 86                         Mozambique       MZ-I        Inhambane
# 87                           Tanzania      TZ-05           Kagera
# 88                           Tanzania      TZ-05           Kagera
# 92                           Tanzania      TZ-13             Mara
# 94                           Tanzania      TZ-25            Tanga
# 96                           Tanzania      TZ-26          Manyara
# 97                             Uganda       UG-E   Eastern Region
# 98                             Uganda       UG-E   Eastern Region
# 100                            Uganda       UG-W   Western Region
#
#                     admin2_name       taxon  year  quarter  \
# 0                        Luanda    coluzzii  2009        2
# 4                         Houet    coluzzii  2012        3
# 5                         Houet    coluzzii  2014        3
# 6                         Houet     gambiae  2012        3
# 7                         Houet     gambiae  2014        3
# 8                     Gbadolite     gambiae  2015        3
# 12                       Bangui     gambiae  1994        1
# 13                Agneby-Tiassa    coluzzii  2012       -1
# 27                   Haut-Nyong     gambiae  2009        3
# 28                Lom-Et-Djérem     gambiae  2009        3
# 45                   Libreville     gambiae  2000        4
# 48   Twifu Heman/Lower Denkyira    coluzzii  2012        3
# 50                   New Juaben     gambiae  2012        4
# 51            Shama Ahanta East    coluzzii  2012        3
# 54                 Fulladu West        gcx2  2012        4
# 55              Central Baddibu        gcx1  2011        3
# 60                  Kissidougou     gambiae  2012        4
# 62                      Macenta     gambiae  2012        4
# 64               Setor De Safim        gcx1  2010       -1
# 65     Bissau Autonomous Sector        gcx1  2010       -1
# 70                       Kilifi        gcx3  2012       -1
# 71                      Kangaba     gambiae  2004        3
# 73                         Kati    coluzzii  2014        3
# 75                         Kati     gambiae  2014        3
# 76                    Yanfolila    coluzzii  2012        4
# 77                    Yanfolila     gambiae  2012        4
# 83                     Chikwawa  arabiensis  2015        2
# 85                   Morrumbene     gambiae  2004        1
# 86                   Morrumbene     gambiae  2004        2
# 87                       Muleba  arabiensis  2015        1
# 88                       Muleba  arabiensis  2015        2
# 92                       Tarime  arabiensis  2012        3
# 94                       Muheza     gambiae  2013        1
# 96                        Moshi  arabiensis  2012        3
# 97                       Tororo  arabiensis  2012        4
# 98                       Tororo     gambiae  2012        4
# 100                     Kanungu     gambiae  2012        4
#
#                                           cohort_label  \
# 0               Angola / Luanda / coluzzii / 2009 / Q2
# 4          Burkina Faso / Houet / coluzzii / 2012 / Q3
# 5          Burkina Faso / Houet / coluzzii / 2014 / Q3
# 6           Burkina Faso / Houet / gambiae / 2012 / Q3
# 7           Burkina Faso / Houet / gambiae / 2014 / Q3
# 8    Democratic Republic of the Congo / Gbadolite /...
# 12   Central African Republic / Bangui / gambiae / ...
# 13     Cote d'Ivoire / Agneby-Tiassa / coluzzii / 2012
# 27         Cameroon / Haut-Nyong / gambiae / 2009 / Q3
# 28      Cameroon / Lom-Et-Djérem / gambiae / 2009 / Q3
# 45            Gabon / Libreville / gambiae / 2000 / Q4
# 48   Ghana / Twifu Heman/Lower Denkyira / coluzzii ...
# 50            Ghana / New Juaben / gambiae / 2012 / Q4
# 51    Ghana / Shama Ahanta East / coluzzii / 2012 / Q3
# 54       Gambia, The / Fulladu West / gcx2 / 2012 / Q4
# 55    Gambia, The / Central Baddibu / gcx1 / 2011 / Q3
# 60          Guinea / Kissidougou / gambiae / 2012 / Q4
# 62              Guinea / Macenta / gambiae / 2012 / Q4
# 64        Guinea-Bissau / Setor De Safim / gcx1 / 2010
# 65   Guinea-Bissau / Bissau Autonomous Sector / gcx...
# 70                        Kenya / Kilifi / gcx3 / 2012
# 71                Mali / Kangaba / gambiae / 2004 / Q3
# 73                  Mali / Kati / coluzzii / 2014 / Q3
# 75                   Mali / Kati / gambiae / 2014 / Q3
# 76             Mali / Yanfolila / coluzzii / 2012 / Q4
# 77              Mali / Yanfolila / gambiae / 2012 / Q4
# 83          Malawi / Chikwawa / arabiensis / 2015 / Q2
# 85       Mozambique / Morrumbene / gambiae / 2004 / Q1
# 86       Mozambique / Morrumbene / gambiae / 2004 / Q2
# 87          Tanzania / Muleba / arabiensis / 2015 / Q1
# 88          Tanzania / Muleba / arabiensis / 2015 / Q2
# 92          Tanzania / Tarime / arabiensis / 2012 / Q3
# 94             Tanzania / Muheza / gambiae / 2013 / Q1
# 96           Tanzania / Moshi / arabiensis / 2012 / Q3
# 97            Uganda / Tororo / arabiensis / 2012 / Q4
# 98               Uganda / Tororo / gambiae / 2012 / Q4
# 100             Uganda / Kanungu / gambiae / 2012 / Q4
#
#                                           sample_query
# 0    cohort_admin2_quarter == 'AO-LUA_Luanda_colu_2...
# 4    cohort_admin2_quarter == 'BF-09_Houet_colu_201...
# 5    cohort_admin2_quarter == 'BF-09_Houet_colu_201...
# 6    cohort_admin2_quarter == 'BF-09_Houet_gamb_201...
# 7    cohort_admin2_quarter == 'BF-09_Houet_gamb_201...
# 8    cohort_admin2_quarter == 'CD-NU_Gbadolite_gamb...
# 12   cohort_admin2_quarter == 'CF-BGF_Bangui_gamb_1...
# 13   cohort_admin2_quarter == 'CI-LG_Agneby-Tiassa_...
# 27   cohort_admin2_quarter == 'CM-ES_Haut-Nyong_gam...
# 28   cohort_admin2_quarter == 'CM-ES_Lom-Et-Djérem_...
# 45   cohort_admin2_quarter == 'GA-1_Libreville_gamb...
# 48   cohort_admin2_quarter == 'GH-CP_Twifu-Heman-Lo...
# 50   cohort_admin2_quarter == 'GH-EP_New-Juaben_gam...
# 51   cohort_admin2_quarter == 'GH-WP_Shama-Ahanta-E...
# 54   cohort_admin2_quarter == 'GM-M_Fulladu-West_gc...
# 55   cohort_admin2_quarter == 'GM-N_Central-Baddibu...
# 60   cohort_admin2_quarter == 'GN-F_Kissidougou_gam...
# 62   cohort_admin2_quarter == 'GN-N_Macenta_gamb_20...
# 64   cohort_admin2_quarter == 'GW-BM_Setor-De-Safim...
# 65   cohort_admin2_quarter == 'GW-BS_Bissau-Autonom...
# 70   cohort_admin2_quarter == 'KE-14_Kilifi_gcx3_20...
# 71   cohort_admin2_quarter == 'ML-2_Kangaba_gamb_20...
# 73   cohort_admin2_quarter == 'ML-2_Kati_colu_2014_...
# 75   cohort_admin2_quarter == 'ML-2_Kati_gamb_2014_...
# 76   cohort_admin2_quarter == 'ML-3_Yanfolila_colu_...
# 77   cohort_admin2_quarter == 'ML-3_Yanfolila_gamb_...
# 83   cohort_admin2_quarter == 'MW-S_Chikwawa_arab_2...
# 85   cohort_admin2_quarter == 'MZ-I_Morrumbene_gamb...
# 86   cohort_admin2_quarter == 'MZ-I_Morrumbene_gamb...
# 87   cohort_admin2_quarter == 'TZ-05_Muleba_arab_20...
# 88   cohort_admin2_quarter == 'TZ-05_Muleba_arab_20...
# 92   cohort_admin2_quarter == 'TZ-13_Tarime_arab_20...
# 94   cohort_admin2_quarter == 'TZ-25_Muheza_gamb_20...
# 96   cohort_admin2_quarter == 'TZ-26_Moshi_arab_201...
# 97   cohort_admin2_quarter == 'UG-E_Tororo_arab_201...
# 98   cohort_admin2_quarter == 'UG-E_Tororo_gamb_201...
# 100  cohort_admin2_quarter == 'UG-W_Kanungu_gamb_20...

# %%
df_cohorts_selected.to_csv(here() / "build/cohorts.csv", index=False)
