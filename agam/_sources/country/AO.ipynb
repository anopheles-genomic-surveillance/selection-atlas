# %%
# Notebook parameters. Values here are for development only and
# will be overridden when running via snakemake and papermill.

config_file = "../../../config/afun.yaml"
country = "MZ"

# %%
# Parameters
country = "AO"
config_file = "/home/runner/work/selection-atlas/selection-atlas/config/agam.yaml"

# %%
from bokeh.io import output_notebook
from IPython.display import Markdown
from selection_atlas.setup import AtlasSetup
from selection_atlas.page_utils import AtlasPageUtils

# Initialise the atlas setup.
setup = AtlasSetup(config_file)
page_utils = AtlasPageUtils(setup=setup)

# N.B., do not add the "remove-output" tag to this cell!!! If you do,
# the bokeh javascript libraries will not get loaded in the generated
# HTML page. The call to output_notebook() injects javascript in the
# cell output which triggers the bokeh javascript libraries to be loaded
# in the page.
output_notebook(hide_banner=True)

# %%
gdf_cohorts_country = page_utils.gdf_cohorts.query(f"country_alpha2 == '{country}'")
country_name = gdf_cohorts_country["country"].unique()[0]

# %% [markdown]
# # Angola

# %% [markdown]
# ## Selection signals
#
# {term}`Selection signal`s found in {term}`cohort`s within this country are shown in the figures below.

# %%
for contig in setup.contigs:
    display(Markdown(f"### Chromosome {contig}"))
    df_signals = page_utils.load_signals(
        contig=contig, query=f"country_alpha2 == '{country}'"
    )
    if len(df_signals) > 0:
        page_utils.plot_signals(df=df_signals, contig=contig)
    else:
        display(Markdown("No signals found."))
# Out:
# ### Chromosome 2RL
# No signals found.
# ### Chromosome 3RL
# No signals found.
# ### Chromosome X
# No signals found.

# %% [markdown]
# ## Selection scans

# %% [markdown]
# The map below shows geographical regions where mosquito genomic data are available and {term}`genome-wide selection scan`s have been performed.
#
# Click on a map marker to see more information about mosquito {term}`cohort`s for which results are available.

# %%
page_utils.plot_cohorts_map(
    gdf_cohorts=gdf_cohorts_country,
    zoom=4,
    url_prefix="../",
)
# Out:
# Map(center=[-8.833069884922793, 13.26367660628238], controls=(ZoomControl(options=['position', 'zoom_in_text',…

# %%
page_utils.style_cohorts_table(
    gdf_cohorts_country,
    caption=f"Table 1. Cohorts analysed within {country_name}.",
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e52c8">
#   <caption>Table 1. Cohorts analysed within Angola.</caption>
#   <thead>
#     <tr>
#       <th id="T_e52c8_level0_col0" class="col_heading level0 col0" >Cohort</th>
#       <th id="T_e52c8_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_e52c8_level0_col2" class="col_heading level0 col2" >Region</th>
#       <th id="T_e52c8_level0_col3" class="col_heading level0 col3" >District</th>
#       <th id="T_e52c8_level0_col4" class="col_heading level0 col4" >Taxon</th>
#       <th id="T_e52c8_level0_col5" class="col_heading level0 col5" >Year</th>
#       <th id="T_e52c8_level0_col6" class="col_heading level0 col6" >Quarter</th>
#       <th id="T_e52c8_level0_col7" class="col_heading level0 col7" >Sample Size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e52c8_row0_col0" class="data row0 col0" ><a href="../cohort/AO-LUA_Luanda_colu_2009_Q2.html">Angola / Luanda / coluzzii / 2009 / Q2</a></td>
#       <td id="T_e52c8_row0_col1" class="data row0 col1" >Angola</td>
#       <td id="T_e52c8_row0_col2" class="data row0 col2" >Luanda</td>
#       <td id="T_e52c8_row0_col3" class="data row0 col3" >Luanda</td>
#       <td id="T_e52c8_row0_col4" class="data row0 col4" >coluzzii</td>
#       <td id="T_e52c8_row0_col5" class="data row0 col5" >2009</td>
#       <td id="T_e52c8_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_e52c8_row0_col7" class="data row0 col7" >77</td>
#     </tr>
#   </tbody>
# </table>
