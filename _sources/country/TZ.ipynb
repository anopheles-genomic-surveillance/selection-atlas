# %%
# Notebook parameters. Values here are for development only and
# will be overridden when running via snakemake and papermill.
country = "ML"
contigs = ["3L"]
analysis_version = "2025.02.13"
dask_scheduler = "single-threaded"
cohorts_analysis = "20240924"

# %%
# Parameters
analysis_version = "2025.02.25"
min_cohort_size = 15
max_cohort_size = 100
sample_sets = [
    "3.0",
    "1237-VO-BJ-DJOGBENOU-VMF00050",
    "1237-VO-BJ-DJOGBENOU-VMF00067",
    "1244-VO-GH-YAWSON-VMF00051",
    "1245-VO-CI-CONSTANT-VMF00054",
    "1253-VO-TG-DJOGBENOU-VMF00052",
    "1178-VO-UG-LAWNICZAK-VMF00025",
    "1244-VO-GH-YAWSON-VMF00149",
    "barron-2019",
    "crawford-2016",
    "tennessen-2021",
    "bergey-2019",
    "campos-2021",
    "fontaine-2015-rebuild",
]
sample_query = "taxon in ['gambiae', 'coluzzii', 'arabiensis', 'bissau']"
contigs = ["2RL", "3RL", "X"]
cohorts_analysis = "20240924"
h12_calibration_contig = "3L"
h12_signal_detection_min_delta_aic = 1000
h12_signal_detection_min_stat_max = 0.1
h12_signal_detection_gflanks = [6]
dask_scheduler = "single-threaded"
alerts = ["01", "02", "03", "04", "05", "06", "07", "08", "09"]
country = "TZ"

# %%
from pyprojroot import here

root = here()
# %run -i {root}/workflow/common/scripts/setup.py
# %run -i {root}/workflow/site/scripts/page-setup.py

# N.B., do not add the "remove-output" tag to this cell!!! If you do,
# the bokeh javascript libraries will not get loaded in the generated
# HTML page. The call to output_notebook() injects javascript in the
# cell output which triggers the bokeh javascript libraries to be loaded
# in the page.
output_notebook(hide_banner=True)

# %% [markdown]
# # Tanzania

# %% [markdown]
# The map below shows regions where mosquito genomic data are available and genome-wide
# selection scans have been performed.
#
# Click on a region to see more information about mosquito cohorts for which data are
# available.

# %%
gdf_cohorts_country = gdf_cohorts.query(f"country_alpha2 == '{country}'")

# %%
plot_cohorts_map(gdf_cohorts=gdf_cohorts_country, zoom=6, url_prefix="../")
# Out:
# Map(center=[-2.9733392496249507, 35.557154959462366], controls=(ZoomControl(options=['position', 'zoom_in_text…

# %% [markdown]
# <br></br>

# %%
def make_clickable(url, name):
    return '<a href="{}" rel="noopener noreferrer" target="_blank">{}</a>'.format(
        url, name
    )

# %%
gdf_cohorts = gdf_cohorts_country.reset_index()
gdf_cohorts["url"] = "../cohort/" + gdf_cohorts["cohort_id"] + ".html"
gdf_cohorts["cohort_label"] = gdf_cohorts.apply(
    lambda x: make_clickable(x["url"], x["cohort_label"]), axis=1
)

gdf_cohorts = gdf_cohorts[
    [
        "cohort_label",
        "admin1_name",
        "admin2_name",
        "taxon",
        "year",
        "quarter",
        "cohort_size",
    ]
]
gdf_cohorts = gdf_cohorts.rename(
    columns={
        "cohort_label": "Cohort",
    }
).set_index("Cohort")
gdf_cohorts.columns = [
    "Region",
    "District",
    "Taxon",
    "Year",
    "Quarter",
    "Sample Size",
]
gdf_cohorts.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_dfd1e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dfd1e_level0_col0" class="col_heading level0 col0" >Region</th>
#       <th id="T_dfd1e_level0_col1" class="col_heading level0 col1" >District</th>
#       <th id="T_dfd1e_level0_col2" class="col_heading level0 col2" >Taxon</th>
#       <th id="T_dfd1e_level0_col3" class="col_heading level0 col3" >Year</th>
#       <th id="T_dfd1e_level0_col4" class="col_heading level0 col4" >Quarter</th>
#       <th id="T_dfd1e_level0_col5" class="col_heading level0 col5" >Sample Size</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Cohort</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dfd1e_level0_row0" class="row_heading level0 row0" ><a href="../cohort/TZ-05_Muleba_arab_2015_Q1.html" rel="noopener noreferrer" target="_blank">Tanzania / Muleba / arabiensis / 2015 / Q1</a></th>
#       <td id="T_dfd1e_row0_col0" class="data row0 col0" >Kagera</td>
#       <td id="T_dfd1e_row0_col1" class="data row0 col1" >Muleba</td>
#       <td id="T_dfd1e_row0_col2" class="data row0 col2" >arabiensis</td>
#       <td id="T_dfd1e_row0_col3" class="data row0 col3" >2015</td>
#       <td id="T_dfd1e_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_dfd1e_row0_col5" class="data row0 col5" >39</td>
#     </tr>
#     <tr>
#       <th id="T_dfd1e_level0_row1" class="row_heading level0 row1" ><a href="../cohort/TZ-05_Muleba_arab_2015_Q2.html" rel="noopener noreferrer" target="_blank">Tanzania / Muleba / arabiensis / 2015 / Q2</a></th>
#       <td id="T_dfd1e_row1_col0" class="data row1 col0" >Kagera</td>
#       <td id="T_dfd1e_row1_col1" class="data row1 col1" >Muleba</td>
#       <td id="T_dfd1e_row1_col2" class="data row1 col2" >arabiensis</td>
#       <td id="T_dfd1e_row1_col3" class="data row1 col3" >2015</td>
#       <td id="T_dfd1e_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_dfd1e_row1_col5" class="data row1 col5" >98</td>
#     </tr>
#     <tr>
#       <th id="T_dfd1e_level0_row2" class="row_heading level0 row2" ><a href="../cohort/TZ-05_Muleba_gamb_2015_Q2.html" rel="noopener noreferrer" target="_blank">Tanzania / Muleba / gambiae / 2015 / Q2</a></th>
#       <td id="T_dfd1e_row2_col0" class="data row2 col0" >Kagera</td>
#       <td id="T_dfd1e_row2_col1" class="data row2 col1" >Muleba</td>
#       <td id="T_dfd1e_row2_col2" class="data row2 col2" >gambiae</td>
#       <td id="T_dfd1e_row2_col3" class="data row2 col3" >2015</td>
#       <td id="T_dfd1e_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_dfd1e_row2_col5" class="data row2 col5" >18</td>
#     </tr>
#     <tr>
#       <th id="T_dfd1e_level0_row3" class="row_heading level0 row3" ><a href="../cohort/TZ-13_Tarime_arab_2012_Q3.html" rel="noopener noreferrer" target="_blank">Tanzania / Tarime / arabiensis / 2012 / Q3</a></th>
#       <td id="T_dfd1e_row3_col0" class="data row3 col0" >Mara</td>
#       <td id="T_dfd1e_row3_col1" class="data row3 col1" >Tarime</td>
#       <td id="T_dfd1e_row3_col2" class="data row3 col2" >arabiensis</td>
#       <td id="T_dfd1e_row3_col3" class="data row3 col3" >2012</td>
#       <td id="T_dfd1e_row3_col4" class="data row3 col4" >3</td>
#       <td id="T_dfd1e_row3_col5" class="data row3 col5" >47</td>
#     </tr>
#     <tr>
#       <th id="T_dfd1e_level0_row4" class="row_heading level0 row4" ><a href="../cohort/TZ-25_Muheza_gamb_2013_Q1.html" rel="noopener noreferrer" target="_blank">Tanzania / Muheza / gambiae / 2013 / Q1</a></th>
#       <td id="T_dfd1e_row4_col0" class="data row4 col0" >Tanga</td>
#       <td id="T_dfd1e_row4_col1" class="data row4 col1" >Muheza</td>
#       <td id="T_dfd1e_row4_col2" class="data row4 col2" >gambiae</td>
#       <td id="T_dfd1e_row4_col3" class="data row4 col3" >2013</td>
#       <td id="T_dfd1e_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_dfd1e_row4_col5" class="data row4 col5" >32</td>
#     </tr>
#     <tr>
#       <th id="T_dfd1e_level0_row5" class="row_heading level0 row5" ><a href="../cohort/TZ-26_Moshi_arab_2012_Q3.html" rel="noopener noreferrer" target="_blank">Tanzania / Moshi / arabiensis / 2012 / Q3</a></th>
#       <td id="T_dfd1e_row5_col0" class="data row5 col0" >Manyara</td>
#       <td id="T_dfd1e_row5_col1" class="data row5 col1" >Moshi</td>
#       <td id="T_dfd1e_row5_col2" class="data row5 col2" >arabiensis</td>
#       <td id="T_dfd1e_row5_col3" class="data row5 col3" >2012</td>
#       <td id="T_dfd1e_row5_col4" class="data row5 col4" >3</td>
#       <td id="T_dfd1e_row5_col5" class="data row5 col5" >39</td>
#     </tr>
#   </tbody>
# </table>
