# %%
# Notebook parameters. Values here are for development only and 
# will be overridden when running via snakemake and papermill.
country = 'ML'
use_gcs_cache = False
dask_scheduler = "threads"

# %%
# Parameters
country = "AO"

# %%
from pyprojroot import here
import geopandas as gpd
import dask
dask.config.set(scheduler=dask_scheduler);

# %% [markdown]
# # Angola

# %% [markdown]
# The map below shows regions where mosquito genomic data are available and genome-wide
# selection scans have been performed.
#
# Click on a region to see more information about mosquito cohorts for which data are
# available.

# %%
gdf_cohorts = gpd.read_file(here() / "build" / "final_cohorts.geojson").set_index('cohort_id')
gdf_cohorts = gdf_cohorts.query(f"country_alpha2 == '{country}'")

# %%
from ipyleaflet import Map, Marker, basemaps, AwesomeIcon
from ipywidgets import HTML

center = gdf_cohorts[['latitude', 'longitude']].mean().to_list()
m = Map(center=center, zoom=7, basemap=basemaps.OpenTopoMap)

for shapeID in gdf_cohorts.shapeID.unique():

    df = gdf_cohorts.query("shapeID == @shapeID")    
    html_text = '<br>'.join([
                                f'<a href="../cohort/{coh_id}.html">{row.cohort_label} (n={row.cohort_size})</a>' 
                                for coh_id, row in df.iterrows()
                            ])

    lat, long = df[['representative_lat', 'representative_lon']].drop_duplicates().values[0]

    icon1 = AwesomeIcon(
        name='bug',
        marker_color="gray",
        icon_color='white',
        spin=False
    )
    
    marker = Marker(location=(lat, long), icon=icon1, draggable=False, opacity=0.7, color="gray")
    m.add_layer(marker);
    
    message2 = HTML()
    message2.value = html_text
    marker.popup = message2

m
# Out:
# Map(center=[-8.884, 13.302], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom…

# %% [markdown]
# <br></br>

# %%
def make_clickable(url, name):
    return '<a href="{}" rel="noopener noreferrer" target="_blank">{}</a>'.format(url,name)

# %%
gdf_cohorts = gdf_cohorts.reset_index()
gdf_cohorts['url'] = "../cohort/" + gdf_cohorts['cohort_id'] + ".html"
gdf_cohorts['cohort_label'] = gdf_cohorts.apply(lambda x: make_clickable(x['url'], x['cohort_label']), axis=1)

gdf_cohorts = gdf_cohorts[['cohort_label', 'cohort_size', 'admin1_name', 'admin2_name', 'taxon', 'year', 'quarter']]
gdf_cohorts = gdf_cohorts.rename(columns={'cohort_label':'Cohort label'}).set_index('Cohort label')
gdf_cohorts.columns = ['Cohort size', 'Admin1 area', 'Admin2 area', 'Taxon', 'Year', 'Quarter']
gdf_cohorts.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_2e965">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e965_level0_col0" class="col_heading level0 col0" >Cohort size</th>
#       <th id="T_2e965_level0_col1" class="col_heading level0 col1" >Admin1 area</th>
#       <th id="T_2e965_level0_col2" class="col_heading level0 col2" >Admin2 area</th>
#       <th id="T_2e965_level0_col3" class="col_heading level0 col3" >Taxon</th>
#       <th id="T_2e965_level0_col4" class="col_heading level0 col4" >Year</th>
#       <th id="T_2e965_level0_col5" class="col_heading level0 col5" >Quarter</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Cohort label</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e965_level0_row0" class="row_heading level0 row0" ><a href="../cohort/AO-LUA_Luanda_colu_2009_Q2.html" rel="noopener noreferrer" target="_blank">Angola / Luanda / coluzzii / 2009 / Q2</a></th>
#       <td id="T_2e965_row0_col0" class="data row0 col0" >77</td>
#       <td id="T_2e965_row0_col1" class="data row0 col1" >Luanda</td>
#       <td id="T_2e965_row0_col2" class="data row0 col2" >Luanda</td>
#       <td id="T_2e965_row0_col3" class="data row0 col3" >coluzzii</td>
#       <td id="T_2e965_row0_col4" class="data row0 col4" >2009</td>
#       <td id="T_2e965_row0_col5" class="data row0 col5" >2</td>
#     </tr>
#   </tbody>
# </table>
