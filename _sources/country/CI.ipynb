# %%
# Notebook parameters. Values here are for development only and
# will be overridden when running via snakemake and papermill.
country = "ML"
analysis_version = "2025.02.07"
dask_scheduler = "single-threaded"
cohorts_analysis = "20240924"

# %%
# Parameters
analysis_version = "2025.02.12"
min_cohort_size = 15
max_cohort_size = 50
sample_sets = [
    "AG1000G-ML-A",
    "AG1000G-BF-A",
    "AG1000G-AO",
    "AG1000G-CD",
    "AG1000G-CI",
    "AG1000G-UG",
    "AG1000G-TZ",
]
contigs = ["2RL", "3RL", "X"]
cohorts_analysis = "20240924"
h12_calibration_contig = "3L"
h12_signal_detection_min_delta_aic = 1000
h12_signal_detection_min_stat_max = 0.1
h12_signal_detection_gflanks = [6]
dask_scheduler = "single-threaded"
alerts = ["01", "02", "03", "04", "05", "06", "07", "08", "09"]
country = "CI"

# %%
from pyprojroot import here

root = here()
# %run -i {root}/workflow/common/scripts/setup.py
# %run -i {root}/workflow/site/scripts/page-setup.py

# N.B., do not add the "remove-output" tag to this cell!!! If you do,
# the bokeh javascript libraries will not get loaded in the generated
# HTML page. The call to output_notebook() injects javascript in the
# cell output which triggers the bokeh javascript libraries to be loaded
# in the page.
output_notebook(hide_banner=True)

# %% [markdown]
# # Cote d'Ivoire

# %% [markdown]
# The map below shows regions where mosquito genomic data are available and genome-wide
# selection scans have been performed.
#
# Click on a region to see more information about mosquito cohorts for which data are
# available.

# %%
gdf_cohorts_country = gdf_cohorts.query(f"country_alpha2 == '{country}'")

# %%
from ipyleaflet import Map, Marker, basemaps, AwesomeIcon
from ipywidgets import HTML

center = gdf_cohorts[["latitude", "longitude"]].mean().to_list()
m = Map(center=center, zoom=7, basemap=basemaps.OpenTopoMap)

for shapeID in gdf_cohorts.shapeID.unique():
    df = gdf_cohorts.query("shapeID == @shapeID")
    html_text = "<br>".join(
        [
            f'<a href="../cohort/{coh_id}.html">{row.cohort_label} (n={row.cohort_size})</a>'
            for coh_id, row in df.iterrows()
        ]
    )

    lat, long = (
        df[["representative_lat", "representative_lon"]].drop_duplicates().values[0]
    )

    icon1 = AwesomeIcon(name="bug", marker_color="gray", icon_color="white", spin=False)

    marker = Marker(
        location=(lat, long), icon=icon1, draggable=False, opacity=0.7, color="gray"
    )
    m.add_layer(marker)
    message2 = HTML()
    message2.value = html_text
    marker.popup = message2

m
# Out:
# Map(center=[2.1581105182926827, 19.227105028948017], controls=(ZoomControl(options=['position', 'zoom_in_text'…

# %% [markdown]
# <br></br>

# %%
def make_clickable(url, name):
    return '<a href="{}" rel="noopener noreferrer" target="_blank">{}</a>'.format(
        url, name
    )

# %%
gdf_cohorts = gdf_cohorts_country.reset_index()
gdf_cohorts["url"] = "../cohort/" + gdf_cohorts["cohort_id"] + ".html"
gdf_cohorts["cohort_label"] = gdf_cohorts.apply(
    lambda x: make_clickable(x["url"], x["cohort_label"]), axis=1
)

gdf_cohorts = gdf_cohorts[
    [
        "cohort_label",
        "cohort_size",
        "admin1_name",
        "admin2_name",
        "taxon",
        "year",
        "quarter",
    ]
]
gdf_cohorts = gdf_cohorts.rename(columns={"cohort_label": "Cohort label"}).set_index(
    "Cohort label"
)
gdf_cohorts.columns = [
    "Cohort size",
    "Admin1 area",
    "Admin2 area",
    "Taxon",
    "Year",
    "Quarter",
]
gdf_cohorts.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_2ac29">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ac29_level0_col0" class="col_heading level0 col0" >Cohort size</th>
#       <th id="T_2ac29_level0_col1" class="col_heading level0 col1" >Admin1 area</th>
#       <th id="T_2ac29_level0_col2" class="col_heading level0 col2" >Admin2 area</th>
#       <th id="T_2ac29_level0_col3" class="col_heading level0 col3" >Taxon</th>
#       <th id="T_2ac29_level0_col4" class="col_heading level0 col4" >Year</th>
#       <th id="T_2ac29_level0_col5" class="col_heading level0 col5" >Quarter</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Cohort label</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ac29_level0_row0" class="row_heading level0 row0" ><a href="../cohort/CI-LG_Agneby-Tiassa_colu_2012.html" rel="noopener noreferrer" target="_blank">Cote d'Ivoire / Agneby-Tiassa / coluzzii / 2012</a></th>
#       <td id="T_2ac29_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_2ac29_row0_col1" class="data row0 col1" >Lagunes</td>
#       <td id="T_2ac29_row0_col2" class="data row0 col2" >Agneby-Tiassa</td>
#       <td id="T_2ac29_row0_col3" class="data row0 col3" >coluzzii</td>
#       <td id="T_2ac29_row0_col4" class="data row0 col4" >2012</td>
#       <td id="T_2ac29_row0_col5" class="data row0 col5" >-1</td>
#     </tr>
#   </tbody>
# </table>
